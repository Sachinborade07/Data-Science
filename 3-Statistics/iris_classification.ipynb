# %%
# This is Hello World to Data Science

# %% [markdown]
# # 1. Importing Module

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # 2. Reading the file

# %%
iris = pd.read_csv("csv/iris.csv")

# %%
# Checking the shape of the data
iris.shape
# Out:
# (150, 5)

# %%
# Checking the columns 
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Checking the data type of each column 
iris.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %% [markdown]
# # To check the data whether it is Discrete or Continuous

# %%
set(iris['sepal_length'])
'''
sepal_length    Continuous Data
sepal_width     Continuous Data
petal_length    Continuous Data    
petal_width     Continuous Data
'''
# Out:
# '\nsepal_length    Continuous Data\nsepal_width     Continuous Data\npetal_length    Continuous Data    \npetal_width     Continuous Data\n'

# %% [markdown]
# # Checking the Output Column

# %%
iris['species'].value_counts()
# From here we can the data is Categorical Containing the three categories
'''
setosa        50
versicolor    50
virginica     50
'''
# Out:
# '\nsetosa        50\nversicolor    50\nvirginica     50\n'

# %% [markdown]
# # Performing UNIVARIATE and BIVARIATE analysis.

# %%
iris.plot(kind='scatter',x='sepal_length',y='sepal_width');
plt.show()

# %%
iris.plot(kind='scatter',x='sepal_length',y='sepal_width');
plt.show()
# Let's modify the scatter plot
sns.set_style("whitegrid");
sns.FacetGrid(iris,hue="species",height=4)\
    .map(plt.scatter,'sepal_length','sepal_width')\
    .add_legend()
plt.show()
plt.close();

# %%
# So from both the graph we can see based on
# sepal_length and sepal_width we can linearly seperate the SETOSA flower

# %% [markdown]
# # pair plot

# %%
sns.set_style("whitegrid")
sns.pairplot(iris,hue="species",height=3)
plt.show()
# Out:
# /home/sachin/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/sachin/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/sachin/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# Unvariate Analysis

# %%
import numpy as np
iris_setosa = iris.loc[iris["species"] == "setosa"]
iris_virginica = iris.loc[iris["species"] == "virginica"]
iris_versicolor = iris.loc[iris["species"] == "versicolor"]
plt.plot(iris_setosa["petal_length"],np.zeros_like(iris_setosa['petal_length']))
plt.plot(iris_virginica["petal_length"],np.zeros_like(iris_virginica['petal_length']))
plt.plot(iris_versicolor["petal_length"],np.zeros_like(iris_versicolor['petal_length']))
plt.show()

# %%
import seaborn as sns

# %%
sns.FacetGrid(iris,hue='species',height=5)\
    .map(sns.distplot,'petal_length')\
    .add_legend();
plt.show()
# Out:
# /home/sachin/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# /home/sachin/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/sachin/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# ...

# %%
from here note  25/7/24
# if petal length is between 3 to 5.5 the chances of vesicolor 
# if petal length is between 3.5 to 7.8 the chances of virginica 
# but it between 4 to 5 then there is chances of misclassification.

# %%
sns.FacetGrid(iris,hue='species',height=5)\
    .map(sns.distplot,'petal_width')\
    .add_legend();
plt.show()
# Out:
# /home/sachin/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# /home/sachin/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/sachin/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# ...

# %%
# There is overlap betweeen setosa and versicolor so we cannot distinguish them

# %%
sns.FacetGrid(iris,hue='species',height=5)\
    .map(sns.distplot,'sepal_width')\
    .add_legend();
plt.show()
# Out:
# /home/sachin/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# /home/sachin/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/sachin/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# ...

# %%
# There is total overlap between SETOSA, VERSICOLOR and VRIGINICA

# %%
counts, bin_edges = np.histogram(iris_setosa['petal_length'],bins=10,density= True)
pdf = counts / (sum(counts))
print(pdf)
print(bin_edges)
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
# Out:
# [0.02 0.02 0.04 0.14 0.24 0.28 0.14 0.08 0.   0.04]
# [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]

# %%
# When petal length is <= 1.6 then we have almost 80% of data points
'''
[ 0.02 0.02   0.04   0.14   0.24   0.28   0.14   0.08   0.     0.04     ]
[ 1.   1.09   1.18   1.27   1.36   1.45   1.54   1.63   1.72   1.81 1.9 ]
'''
